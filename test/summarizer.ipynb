# %%
pip install blobfile torch sentencepiece
# Out:
# Requirement already satisfied: blobfile in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (3.0.0)
# Requirement already satisfied: torch in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (2.5.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: pycryptodomex>=3.8 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from blobfile) (3.21.0)
# Requirement already satisfied: urllib3<3,>=1.25.3 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from blobfile) (2.3.0)
# Requirement already satisfied: lxml>=4.9 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from blobfile) (5.3.0)
# Requirement already satisfied: filelock>=3.0 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from blobfile) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/faizan/miniconda3/envs/genai/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Downloading sentencepiece-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoModelWithLMHead, AutoTokenizer


tokenizer = AutoTokenizer.from_pretrained("mrm8488/t5-base-finetuned-summarize-news")
model = AutoModelWithLMHead.from_pretrained("mrm8488/t5-base-finetuned-summarize-news")

# %%
MAX_TOKEN_LEN = 512

def summarize(text, max_length=150):
  input_ids = tokenizer.encode(text, 
                               return_tensors="pt", 
                               add_special_tokens=True
                               )
  
  # TODO: cater greater than max token length
  # print(len(input_ids[0]))
  generated_ids = model.generate(input_ids=input_ids, 
                                 num_beams=2, 
                                 max_length=max_length,  
                                 repetition_penalty=2.5, 
                                 length_penalty=1.0,
                                 early_stopping=True
                                 )

  preds = [
      tokenizer.decode(g, 
                       skip_special_tokens=True, 
                       clean_up_tokenization_spaces=True
                       ) for g in generated_ids
      ]

  return preds[0]


l_news = """The Indira Gandhi Institute of Medical Sciences (IGIMS) in Patna amended its marital declaration form on Thursday, replacing the word ?virgin? with ?unmarried? after controversy.Until now, new recruits to the super-specialty medical institute in the state capital were required to declare if they were bachelors, widowers or virgins.IGIMS medical superintendent Dr Manish Mandal said institute director Dr NR Biswas held a meeting on Thursday morning before directing that the word ?virgin? on the marital declaration form be immediately replaced with ?unmarried?. Dr Biswas had just returned after a four-day leave of absence.Earlier, Bihar health minister Mangal Pandey had ended up redefining the very meaning of virginity in his attempts to justify the awkward phrasing of the question in the form. Following a public furore over the document on Wednesday, the minister told news channels that there was nothing wrong with using the word ?virgin? because it simply meant ?kanya? or ?kunwari? ? which means an unmarried girl.Pandey had joined the cabinet just three days ago.Sources said the chief minister?s office had also taken cognizance of the issue, and asked for a copy of the form. It had even asked why the question was introduced in the first place.In its response, the management of the autonomous super-specialty health facility had clarified on Wednesday that it was in adherence to the central civil services rules followed by the All India Institute of Medical Sciences in New Delhi.The previous version of the marital declaration form, which purportedly asked new recruits if they were virgins.\r\n\t\t\t\t\t\t\t(HT Photo)\r\n\t\t\t\t\t\tThe marital declaration form had been in existence since the inception of the institute in 1983. Some officials blamed the faux pas on poor translation on the part of individuals who drafted the document.?The word ?virgin? mentioned on the form had nothing to do with the virginity of any employee. It only sought to know the employees? marital status, so their dues could be settled on the basis of their declaration in the event of death while in service,? said Dr Mandal."""

summarize(l_news)
# Out:
# "Indira Gandhi Institute of Medical Sciences (IGIMS) in Patna on Thursday amended its marital declaration form, replacing the word 'virgin' with 'unmarried' after controversy. The institute medical superintendent Dr Manish Mandal said institute director Dr NR Biswas had held a meeting before directing that the word 'virgin' on the form be immediately replaced with 'unmarried'. Some officials blamed the faux pas on poor translation on the part of individuals who drafted the document."
